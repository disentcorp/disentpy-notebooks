# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/anthony/.local/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /home/anthony/.local/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/anthony/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/anthony/.local/lib/python3.8/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /home/anthony/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install disentpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: disentpy in /home/anthony/.local/lib/python3.8/site-packages (0.0.23)
# Requirement already satisfied: requests in /home/anthony/.local/lib/python3.8/site-packages (from disentpy) (2.28.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/anthony/.local/lib/python3.8/site-packages (from requests->disentpy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/anthony/.local/lib/python3.8/site-packages (from requests->disentpy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/anthony/.local/lib/python3.8/site-packages (from requests->disentpy) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/anthony/.local/lib/python3.8/site-packages (from requests->disentpy) (1.26.9)

# %%
import disent
disent.settings.DF_DATE_FORMAT='datetime'

# %%
model="DEMO_EQD_VOLS"
ticker = 'SPX'
model_args = {'ticker':ticker}

# %%
df = disent.hub(model,model_args)
df
# Out:
# Downloaded........ 133.0 KiB done.
#      TCK   MNY        YRS        IV    T         DT
# 0    SPX  0.00   0.079452  0.880071   1M 2022-07-12
# 1    SPX  0.00   0.164384  0.824049   2M 2022-08-12
# 2    SPX  0.00   0.249315  0.771807   3M 2022-09-12
# 3    SPX  0.00   0.498630  0.639125   6M 2022-12-12
# 4    SPX  0.00   0.997260  0.456036   1Y 2023-06-12
# ..   ...   ...        ...       ...  ...        ...
# 715  SPX  2.95   3.000000  0.150751   3Y 2025-06-12
# 716  SPX  2.95   4.000000  0.134240   4Y 2026-06-12
# 717  SPX  2.95   5.000000  0.131936   5Y 2027-06-12
# 718  SPX  2.95   7.002740  0.131936   7Y 2029-06-12
# 719  SPX  2.95  10.005479  0.131936  10Y 2032-06-12
#
# [720 rows x 6 columns]
